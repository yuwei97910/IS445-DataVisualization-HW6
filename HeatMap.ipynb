# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import bqplot
import ipywidgets

data_url = 'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/licenses_fall2022.csv'
df_licenses = pd.read_csv(data_url)
df_licenses.head()
# Out:
#        _id     License Type                      Description License Number  \
# 0  1189509  DETECTIVE BOARD  PERMANENT EMPLOYEE REGISTRATION      129446286
# 1   801037  DETECTIVE BOARD             FIREARM CONTROL CARD    229030294.0
# 2   365129            COSMO           LICENSED COSMETOLOGIST     11053076.0
# 3   595427            COSMO           LICENSED COSMETOLOGIST     11295645.0
# 4   653668            COSMO         LICENSED NAIL TECHNICIAN      169006247
#
#   License Status Business Title First Name Middle  Last Name  ...  \
# 0    NOT RENEWED        N   NaN     EILEEN    NaN  SANTACRUZ  ...
# 1    NOT RENEWED        N   NaN     DAGMAR      J   NORDLUND  ...
# 2    NOT RENEWED        N   NaN     RADOJE    NaN  ZELENOVIC  ...
# 3         ACTIVE        N   NaN  BECKY SUE      L  BURROUGHS  ...
# 4    NOT RENEWED        N   NaN     BILL G      L     LETNER  ...
#
#   Specialty/Qualifier Controlled Substance Schedule  \
# 0                None                          None
# 1                None                          None
# 2                None                          None
# 3                None                          None
# 4                None                          None
#
#   Delegated Controlled Substance Schedule Ever Disciplined LastModifiedDate  \
# 0                                    None                N       03/18/2022
# 1                                    None                N       08/16/2006
# 2                                    None                N       05/26/2006
# 3                                    None                N       11/12/2021
# 4                                    None                N       05/30/2006
#
#   Case Number Action Discipline Start Date Discipline End Date  \
# 0        None   None                  None                None
# 1        None   None                  None                None
# 2        None   None                  None                None
# 3        None   None                  None                None
# 4        None   None                  None                None
#
#   Discipline Reason
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 31 columns]

# %% [markdown]
# ---
# ## NaN's discussion
# The assignment focused on the number of the date difference between Original Issue Date and Expiration Date. There are no missing values for Original Issue Date, while there are 500 records without Expiration Date. We choose to remove the records for further analysis because 500 is relative small number to total 10000 records. The effect of removing them might not cause big issue for visualization.

# %%
df_licenses.isna().sum()
# Out:
# _id                                           0
# License Type                                  0
# Description                                   0
# License Number                               60
# License Status                                0
# Business                                      0
# Title                                      9890
# First Name                                  395
# Middle                                     6378
# Last Name                                   395
# Prefix                                     9997
# Suffix                                     9590
# Business Name                                 0
# BusinessDBA                                9885
# Original Issue Date                           0
# Effective Date                              792
# Expiration Date                             500
# City                                         11
# State                                         0
# Zip                                          71
# County                                      411
# Specialty/Qualifier                          61
# Controlled Substance Schedule                 1
# Delegated Controlled Substance Schedule       0
# Ever Disciplined                              0
# LastModifiedDate                              0
# Case Number                                   0
# Action                                        1
# Discipline Start Date                         0
# Discipline End Date                           0
# Discipline Reason                             0
# dtype: int64

# %%
df_licenses = df_licenses.dropna(subset=['Expiration Date'])

# %%
columns = df_licenses.columns.tolist()
arr_list = []
for column in columns:
    if 'Date' in column:
        arr_list.append(column)
df_licenses[arr_list]
# Out:
#      Original Issue Date Effective Date Expiration Date LastModifiedDate  \
# 0             02/03/2020     02/03/2020      09/30/2021       03/18/2022
# 1             02/07/1995     02/07/1995      12/31/2003       08/16/2006
# 2             02/28/1945     02/28/1945      09/30/1983       05/26/2006
# 3             11/22/2011     11/12/2021      09/30/2023       11/12/2021
# 4             07/12/1995     07/12/1995      10/31/2002       05/30/2006
# ...                  ...            ...             ...              ...
# 9994          12/30/1983     12/30/1983      09/30/1987       05/26/2006
# 9995          08/04/1987     08/04/1987      05/31/1997       08/03/2006
# 9996          05/22/1989     05/22/1989      06/11/1990       08/07/2006
# 9998          10/04/1983     12/17/2021      09/30/2023       12/17/2021
# 9999          10/16/2008     10/25/2021      09/30/2024       10/25/2021
#
#      Discipline Start Date Discipline End Date
# 0                     None                None
# 1                     None                None
# 2                     None                None
# 3                     None                None
# 4                     None                None
# ...                    ...                 ...
# 9994                  None                None
# 9995                  None                None
# 9996                  None                None
# 9998                  None                None
# 9999                  None                None
#
# [9500 rows x 6 columns]

# %%
df_licenses['Diff_Date'] = pd.to_datetime(df_licenses['Expiration Date'], errors='coerce',format='%m/%d/%Y') - pd.to_datetime(df_licenses['Effective Date'],errors='coerce',format='%m/%d/%Y')
df_licenses['Diff_Date'] = df_licenses['Diff_Date'].dt.days
# df_licenses['Diff_Date'].fillna(0, inplace=True)

# %%
licenses_group = df_licenses.groupby(['License Status', 'License Type'])['Diff_Date'].mean()
uniq_status = df_licenses['License Status'].unique()
uniq_type = df_licenses['License Type'].unique()

# %%
def switchYear(column):
    df_licenses[column] = pd.to_datetime(df_licenses[column],errors='coerce',format='%m/%d/%Y').dt.year

# %%
for column in arr_list:
    switchYear(column)
df_licenses[arr_list]
# Out:
#       Original Issue Date  Effective Date  Expiration Date  LastModifiedDate  \
# 0                  2020.0          2020.0           2021.0              2022
# 1                  1995.0          1995.0           2003.0              2006
# 2                  1945.0          1945.0           1983.0              2006
# 3                  2011.0          2021.0           2023.0              2021
# 4                  1995.0          1995.0           2002.0              2006
# ...                   ...             ...              ...               ...
# 9994               1983.0          1983.0           1987.0              2006
# 9995               1987.0          1987.0           1997.0              2006
# 9996               1989.0          1989.0           1990.0              2006
# 9998               1983.0          2021.0           2023.0              2021
# 9999               2008.0          2021.0           2024.0              2021
#
#       Discipline Start Date  Discipline End Date
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
# ...                     ...                  ...
# 9994                    NaN                  NaN
# 9995                    NaN                  NaN
# 9996                    NaN                  NaN
# 9998                    NaN                  NaN
# 9999                    NaN                  NaN
#
# [9500 rows x 6 columns]

# %%
# list1 = df_licenses['Original Issue Date'].unique()
# list1.sort()
# list1

# %%
licenses_group
# Out:
# License Status                        License Type
# ACTIVE                                ARCHITECT             753.750000
#                                       ATHLETIC TRAINER      716.000000
#                                       AUCTIONEER            816.000000
#                                       CLIN PSYCHOLOGIST     692.777778
#                                       COLLECTION AGENCY    1038.285714
#                                                               ...
# Non Sufficient Fund Check Terminated  COSMO                5220.000000
#                                       DETECTIVE BOARD       220.000000
# TERMINATED CARD RETURNED              DETECTIVE BOARD       770.205607
# TERMINATED VALID REASON               DETECTIVE BOARD       834.421053
# TERMINATED WITHOUT CARD               DETECTIVE BOARD      1019.468750
# Name: Diff_Date, Length: 105, dtype: float64

# %%
print(len(uniq_status))
print(len(uniq_type))
# Out:
# 13
# 28

# %%
df_temp = df_licenses[(df_licenses['License Type'] == 'DETECTIVE BOARD') & (df_licenses['License Status'] == 'NOT RENEWED')]
df_median = df_temp.groupby(['Original Issue Date'])['Diff_Date'].median().to_frame().reset_index()

def l_filter(types, status):
    df_temp = df_licenses[(df_licenses['License Type'] == types) & (df_licenses['License Status'] == status)]
    df_median = df_temp.groupby(['Original Issue Date'])['Diff_Date'].median().to_frame().reset_index()
    
    return df_median['Diff_Date'].values

# %%
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.LinearScale()
ax_xcl = bqplot.Axis(label='Original Issue Year', scale=x_sc, tick_rotate=60,label_offset='50', tick_style={'text-anchor': 'start'})
ax_ycl = bqplot.Axis(label='Date Difference', scale=y_sc, label_offset='-45',
                    orientation='vertical')

bar = bqplot.Bars(x=df_median['Original Issue Date'], 
                  y=df_median['Diff_Date'],
                  scales={'x': x_sc, 'y': y_sc})

figh = bqplot.Figure(marks=[bar], axes = [ax_xcl, ax_ycl])
figh
# Out:
# Figure(axes=[Axis(label='Original Issue Year', label_offset='50', scale=OrdinalScale(), tick_rotate=60, tick_s…

# %%
heatmap_data = []
for s in uniq_status:
    status_row = np.array([licenses_group[s][t] if t in licenses_group[s].index else 0 for t in uniq_type])
    heatmap_data.append(status_row)
    
heatmap_data = np.array(heatmap_data)

# %%
label_message = ipywidgets.Label()

# %%
def on_selected(change):
    if len(change['owner'].selected)==1: # only do things if I select a single cell
        #print(change['owner'].selected[0])
        i, j =change['owner'].selected[0]
        v = heatmap_data[i,j]
        selected_type = uniq_type[j]
        selected_status = uniq_status[i]
        bar.y = l_filter(selected_type, selected_status)
        label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'

# 2. Scales
col_sc = bqplot.ColorScale(scheme="RdPu", 
                           min=np.nanmin(heatmap_data),
                           max=np.nanmax(heatmap_data))
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()

# 3. Axis -- skip this for right now
col_ax = bqplot.ColorAxis(scale=col_sc, 
                        # orientation='vertical',
                         side='right')
x_ax = bqplot.Axis(label='Type', scale=x_sc, tick_rotate=15, label_offset='60', tick_style={'text-anchor': 'start', 'font-size': 8})
y_ax = bqplot.Axis(label='Status', scale=y_sc, orientation='vertical', tick_rotate=0, label_offset='-120', tick_style={'text-anchor': 'end', 'font-size': 8})

# 4. Mark -- grid heatmap
heat_map = bqplot.GridHeatMap(color=heatmap_data,
                            row=uniq_status,
                            column=uniq_type,
                            scales={'color':col_sc, 'row':y_sc, 'column':x_sc},
                            interactions={'click':'select'},
                            selected_style={'fill':'magenta'},
                            row_align='start')

# 5. interactions -- skip for now as well
heat_map.observe(on_selected,'selected')

# put it all together as a figure
fig = bqplot.Figure(marks=[heat_map], axes=[col_ax, x_ax, y_ax], fig_margin={'top':30, 'bottom':80, 'left':150, 'right':80})

fig
# Out:
# Figure(axes=[ColorAxis(scale=ColorScale(max=14172.1875, min=-7.0, scheme='RdPu'), side='right'), Axis(label='T…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1369                 for changes in cache.values():
#    1370                     for change in changes:
# -> 1371                         self.notify_change(change)
#    1372
#    1373     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1384     def notify_change(self, change):
#    1385         """Notify observers of a change event"""
# -> 1386         return self._notify_observers(change)
#    1387
#    1388     def _notify_observers(self, event):
#
# ~/opt/anaconda3/envs/python_data_visualization/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1429                 c = getattr(self, c.name)
#    1430
# -> 1431             c(event)
#    1432
#    1433     def _add_notifiers(self, handler, name, type):
#
# /var/folders/zt/nx8qt9y52nx05qjlktydjs1w0000gn/T/ipykernel_79573/3259067466.py in on_selected(change)
#       6         selected_type = uniq_type[j]
#       7         selected_status = uniq_status[i]
# ----> 8         bar.x = list1
#       9         bar.y = l_filter(selected_type, selected_status)
#      10         label_message.value = f'    Selected Box: {(i, j)};\n   Selected Status: {str(selected_status)};\n  Selected Type: {str(selected_type)};\n  Mean of the days between Effective Date and Expiration Date={v:.2f}'
#
# NameError: name 'list1' is not defined

# %%
fig.layout.min_width = '1200px'
figh.layout.min_width = '1200px'

figures = ipywidgets.HBox([fig, figh])

myDashboard = ipywidgets.VBox([label_message, figures])
myDashboard
# Out:
# VBox(children=(Label(value=''), HBox(children=(Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale…

# %% [markdown]
# ### Can you keep the x and y ranges static on the bar plot?

# %% [markdown]
# We tried to keep the x and y ranges static with many ways, like using "tick_values" attribute or even setting the bars.x static. Neither of them works. We think the only way to do that is adding all the years into dataframe and keep all the the value of years which don't exist originally 0. However, we don't think that is a good way since it will waste a lot of space.

# %% [markdown]
# ###    Can you change the style?
